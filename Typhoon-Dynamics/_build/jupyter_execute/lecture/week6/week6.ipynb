# %% [markdown]
# # Typhoon-Dynamics - Week 6
#
# **日期:** 2026.04.01
#
# 是觀測、是模擬要搞清楚
# 做什麼假設要寫清楚、
# 模擬解析度要講

# %% [markdown]
# 200PVU
#
#
# Ooyama 2層的淺水方程+邊界層 描述TC:對稱
# 張庭宇的論文 一層淺水+邊界層 描述TC
#
# 不對稱的動力考慮到wavenumber1 wavenumber2
#
#
# Ooyama :
# * 對流和TC會互相幫助，而不是相互競爭能量。兩層模式:會有積雲參數化的問題(無法直接解析潛熱)
#   * 參數化的意義:每一朵積雲不一定能夠處理，但是合起來的效果可以被診斷出來(積雲1km可以被100km的颱風內部控制住)
# * 邊界層摩擦的重要性
# * 海契交互作用的重要:沒有海洋就沒有颱風
# * TC是軸對稱動力
# * 主次環流的開山始祖
#   * 颱風是平衡動力
#     * 梯度風平衡
#     * Ranking vortex :  $v = v_m (r/r_m) at r<rm$
#   * 主環流繞著軸向[pic]([pic/view.png])
#   *
# * 1967年Ostlund 用氚(同位素)追蹤出來颱風的都是海洋裡蒸發出來的。(同位素定年?)
#
#
#
# ```小補充: 現在可以高解析到500m~100m (LES)```
#
# QG中
# * tendency equation :平衡的東西怎麼變化
# * omega equation : 一個平衡轉到另一個平衡中間要做的調整 (次環流)
#
#
#
# ranking vortex$v = v_m (r/r_m)^a at r<rm$  可以計算渦度
# * $a=0.5$
#   * 渦度從高處緩慢下降，到rm後平穩下降
# * $a=1$
#   * 渦度從固定，到rm後平穩下降
# * $a=2$
#   * 渦度從低處緩慢上升，到rm後平穩下降
#
#
# Ooyama 結果 :
# * TC生成時氣壓不斷下降、風速增加
# * 若把海洋關掉TC直接崩潰
#
#
#
# 我們知道次環流的形狀、rossby deformation 和rossbt hight 由PV，也就是AC-B^2來控制

# %% [markdown]
# ## 仔細觀察
#
# Dvorak technique 是從衛星雲圖看TC強度的方法
#
# 刺激了2019陳柏孚的AI辨識衛星雲圖的 DSAT論文
#
#
#
# 海水重要，新時代衛星能夠量測海水下OHC也提供很多insight
#
#
#
# 垂直風切普遍情況對颱風不利，但是怎麼和中尺度颱風交互
#
#
# 從大尺度的變數似乎看不出為什麼會RI(突然變強)，重點在CE(同心眼牆)、vortex rossby wave(不對稱動力)
#
# * wave mean flow interaction (波動和平均流的交互):使的熱通量可以傳遞 $\bar{w'T'}$ 傳送熱量、 $-\frac{\partial \bar{u_g' v_g'}}{\partial y}$ 改變平均流
# * 對於TC就可以用wave mean flow interaction的觀點，眼牆外渦度小、眼牆渦度大、眼牆內渦度小:在渦度的梯度介面上所以叫渦漩的羅士比波
# * 利用這個不對稱動力了解對稱動力
#
#
# 颱風路徑預報幾乎已經被google模式做得非常準確，但是強度還有能夠努力的空間

# %% [markdown]
# ## 200PVU的動力
#
# $1 \text{PUV} = -10\text{m}\text{s}^{-2} 10^{-4} \text{s}^{-1} \frac{-10\text{K}}{100\text{hPa}} = 10^{-6} m^{2} s^{-1} K kg^{-1}$
#
# $$\text{ PVU} = 10^{-6} \text{ m}^2 \text{K kg}^{-1} \text{s}^{-1}$$
#
# $$\text{m}^2 \text{K kg}^{-1} \text{s}^{-1} = \frac{\text{s}^{-1}}{\text{kg} / (\text{m}^2 \text{K})} = \frac{\text{vorticity units}}{\text{pseudo-density units}}$$
#
# * 跟穩定度
# * 科式力有關係
#
#
# 局部區域有可能可以達到200PVU
#
# * (2019) MWR：Diagnosis of the Dynamic Efficiency of Latent Heat Release and the Rapid Intensification of Supertyphoon Haiyan (2013)
# * (2020) JAS：Potential Vorticity Mixing and Rapid Intensification in the Numerically Simulated Supertyphoon Haiyan (2013)
# * (2021) JAS：Reply to “Comments on ‘Potential Vorticity Mixing and Rapid Intensification in the Numerically Simulated Supertyphoon Haiyan (2013)
#
#
# * 當大尺度條件都一樣 RI is more likely to occur in an intense TC. (Shu et al. 2012)
# * 颱風是 中尺度 (~100km)機器，但是能量來於大尺度(~1000km)，當這個颱風比較強應該是內部有特殊的東西(雙眼牆)，但大尺度一樣重要
#
#
# Martinez et al. 2019 JAS [pic]
# * 下圖黑色箭頭可以看到次環流
# * 白線是對流
# * 中心位渦很大
# * 眼牆和最大上升沒有重和，最大上升處再眼牆之外，在這個對流處的底層發現200PVU，在往內位渦就又變小了
# * 位渦塔:最大上升和位渦最大處重疊
#
# Hausman et al. (2006)
# * 解析度很高(0.5km) 、對稱模式(沒有wavenumber n 或 wave mean flow interaction)、非靜力平衡模式
# * 貼近眼牆的外側對流看到250PVU
# * 沒有考慮不對稱對流
# * 看圖，對流在r-z圖中呈現45度角
# * a narrow, leaning tower in which the value of PV can reach several hundred potential vorticity unit.” (Hausman et al. 2006) : 也就是 Large w and large ζ coupled“ (Tsujino and Kuo 2020)
#
# Carry Emanum
# * 颱風會達到stead state，達到一個強度後就不會更強了(MPI)
# * 但是從數學上會從2~3PVU到10PVU 再到200PVU(跨越兩個尺度)就可以大概認定是exp增長(應該吧)，可能需要別的證據來證明是不是真的有最大上限
#
#
#
#
# 從數學上看公式
#
# $$\frac{DP}{Dt} = P \left( \frac{\partial \dot{\theta}}{\partial \theta} \right)_{\vec{\zeta}}$$
#
# * 加熱被雲微物理、熱力學所限制
# * P沒有被限制，所以可以是指數成長的形式
# * P一定要和 $\left( \frac{\partial \dot{\theta}}{\partial \theta} \right)_{\vec{\zeta}}$ 在空間上耦合再一起TC才會強大
#   * 就像渦度變大要和輻和綁再一起$ \frac{D\zeta}{Dt} = -\zeta \nabla \cdot \vec{v}$
#   * Hank  and  Schuber : 加熱要加在慣性穩定的地方 ，也就是加熱要加在渦度大的地方、加熱要加在位渦大的地方 TC才變得更強 Large w and large ζ coupled (Tsujino and Kuo 2020)
#
#
# 茶壺實驗知道
# * 對流要夠強，如果不夠強則強對流上升到一半就向外輻散了

# %% [markdown]
# ## 200PUV 動力
#
# ### Axisymmetric BL flow on an f-palne
#
# 假設:
# * 沒有 $w \frac{\partial}{\partial z}$
# * 軸對稱
#
# $$\frac{\partial v}{\partial t} = -\left( f + \frac{\partial rv}{r \partial r} \right) u + F_{ric}$$
#
# * 如果有內流($u<0$) 渦度是正的 ，所以 $v$ 要增加
# *
#
# $$\frac{\partial u}{\partial t} + u \frac{\partial u}{\partial r} = \left( fv + \frac{v^2}{r} - \frac{1}{\rho} \frac{\partial p}{\partial r} \right) + F_{ric}$$
#
# * 如果梯度風被破壞會產生內流
# * $u \frac{\partial u}{\partial r}$ 如果考慮非線性動力(不能夠忽略u' ) [pic u 的低平率變高屏綠，造成不連續]
#   * 因為大尺度非線性過程會把梯度變得很尖銳(fft後看就散布在各個頻率上)也有到 小尺度   所以有enegy cascade。流體力學中會自發地把梯度變的尖銳
#     * 風升 也是一個例子
#     * 割離低壓
#     * 化學關心:反映產率正比於介面，也就是梯度大小反映介面多少(反應速度逼近於0、介面逼近無限大)
#
# $\frac{\partial u}{\partial t} + u \frac{\partial u}{\partial r} = 0 $ 如果考慮非線性動力 [pic u 變化]
# 初始給一個hyperbolic tangen 初始非常平滑，隨時間積分變得非常尖銳
#
# $\frac{\partial u}{\partial t} + u \frac{\partial u}{\partial r} = 0$
#
# $u(r,0) = f(x) = u_0 - \Delta u \tan^{-1} (\frac{r-r_0}{h})$
#
# $u(r,t) = u_0 - \Delta u \tan^{-1} (\frac{r - ut - r_0}{h})$
#
# $\frac{\partial u}{\partial r} = - \frac{\Delta u}{h} \frac{1 - t \frac{\partial u}{\partial r}}{1 + (\frac{r - r_0 - ut}{h})^2}$
#
# $(\frac{\partial u}{\partial x})_{x = x_0 + \bar{u}t} = -(1 - t (\frac{\partial u}{\partial x})_{x = x_0 + \bar{u}t})$
#
# $(\frac{\partial u}{\partial r})_{r = r_0 + u_0 t} = \frac{-1}{t - \frac{h}{\Delta u}} \rightarrow -\infty, \quad \text{as } t \rightarrow \frac{h}{\Delta u}$
#
# 在有限的時間內可以達到不連續，會發生
#
# * 弱的颱風這個現象不明顯
#
#
#
# Hurricane Hugo (1989)  觀測!! [pic HH1989]
# * 紅色代表在400m(近地表)觀測到的、藍色代表2.6km(高空)
# * 雖然是某一個角度的觀測，但是可以假設很軸對稱
# * 從紅線來看
#   * 在8km處有20m/s的上升速度
#     * 因為這個以後都不准飛飛機在TC
#     * 8km以內的 u 平均 8m/s 、8km以外的u平均 -20m/s ，代表強烈輻和、很不連續、和w重和、有shock(數值模是碰到都不好過因為 超音速)
#     * 8km以內的 v 平均 20m/s 、8km以外的v平均 80m/s ，這一環渦度很大，因為風切渦度大$\frac{\partial v}{\partial r}$， $\zeta = \frac{1}{r} \frac{\partial (rv)}{\partial r} - \frac{1}{r} \frac{\partial u}{\partial \theta}$
#     * v的下降可以用u和zeta看出來 $\frac{\partial v}{\partial t} = -u(f + \zeta)$ ，而此位置的w也很大
#   * 因為沒有考慮 $w \frac{\partial}{\partial z}$ (?) 、且是否真的軸對稱 是個問題，但是和目前的想法吻合
#   * 會發生在強颱風，若颱風不能在有限的時間內讓U有shock，這個可能是有200PVU的徵兆，但是在本次觀測中沒有特別去觀測驗證這個想法
#   *
# * 從藍線來看 (高空)
#   * 內部渦度小 外部渦度大 :代表有位渦環
#   * `邊界層渦度大的地方` 在 `高空渦度大(風速最大)的地方` 的 `內部`
#   * 上面的v很大轉得很快向鋼體，R方向都進不去，只能從邊界層上來(邊界層有摩擦 spiral in )。中層(高空)加熱效率很好，因為對流都在渦度上或內[pic Martinez 2019 JAS]
#   *
#
#
# Hausman et al. (2006) 的模式
# * 對稱
# * 也有看到這個 u shock和對流w重和造成 v變小且有PV環，
#
#
#
#
# 颱風內部的主要環流是有可能指數成長的
# * 並不代表對流會指數成長
# * PV和 $\dot\theta $ 綁在一起從觀測上看到的就是這件事情(u shock和對流w重和造成 v變小且有PV環)

# %% [markdown]
# ##
#
#
# 給定一個軸對稱颱風的 r-v圖 ，再半徑100km以內v隨r上升，但是是凹向上的上升，可以畫出渦度應該會一開始(25km以內)很小然25~100km會很大，這符合飛機觀測看到的情況(Hurricant Hugo 1989、Hurricane Guillermo (1997))。
# 所以可以畫出一個軸對稱的圓在25~100km有一個渦度環
#
# 從圓心r=0，到渦度環k=50km，到颱風外側k=500km，經歷了渦度小渦度大渦度小，這在動力學上有教過是正壓不穩定
#
#
# 可以觀察渦度方程式，猜會發生什麼事
#
# $\frac{\partial \zeta}{\partial t} + u \frac{\partial \zeta}{\partial x} + v \frac{\partial \zeta}{\partial y} = 0$
#
# 從觀測來說它會局部聚集再一起，成為一群一群的可能項是wave number 10的情況，
# 一群一群渦漩一段時間後在台風內部會相互吸引合併，然後從模式來看似乎到wave number 5 就會形成穩定的結構不再繼續合併(持續很長的時間，後當然還是會合併)
#
# 觀測還不到位、解析度很差的時候，會想討論颱風中心有沒有其他渦漩 ，可是這個文章告訴我們渦漩會出現這五個小渦漩的結構
#
# [Mesovortices, Polygonal Flow Patterns, and Rapid Pressure Falls in Hurricane-Like Vortices 2001 fig9](https://journals.ametsoc.org/view/journals/atsc/58/15/1520-0469_2001_058_2196_mpfpar_2.0.co_2.xml#i1520-0469-58-15-2196-f02)
#
#
# 如果位渦還很粗，最後可能會合併再中心
# 如果位渦還很細，系絲帶也會很細(?)
# * 如果另 $u= -\frac{\partial \psi}{\partial y}, \quad v= \frac{\partial \psi}{\partial x}$
# * \zeta^2 (entropy):\quad k^4 \hat{\psi}_k
# * u^2 + v^2(動能):\quad k^2 \hat{\psi}_k
# * k是波數，所以可以寫成 $k^2_i*K_i=k^2*K$ 所以有內縮就有外放
#
# !大尺度考慮旋轉的效應足夠強、水平進來的都會水平出去(垂直的少)、不考慮摩擦力，基本上entropy、energy就會守恆，然後就會有這個等式$k^2_i*K_i=k^2*K$，當有$k_1$向內移動就勢必要有$k_n$向外移動
#
# * 內縮導致月轉越快動能更大了，但是動能應守恆，所以外圈的變慢
# * 這跟南極臭氧洞是一樣的故事，系絲帶會噴到很遠的地方產生很多介面然後可能飛機的儀器會觀測到O_3突然上升
# * 數值模是在解析系絲帶(Schubert et al. (1999))可能會碰到解析度不夠的問題、包含無法解析高頻率的波
#
# * 計算上系絲帶的index沒有反對稱可能導致某種不守恒 (諾特定裡告訴我們的)
#
# 2002衛星觀測就有看到5角型的內眼牆結構
# MESOVORTICES IN HURRICANE ISABELBY JAMES P. KOSSIN AND WAYNE H. SCHUBERT 2002
#
#
# 位渦環的位渦可以產生一些混和的作用(PV mixing)
# 這個五角形在木星上、電漿學上都有觀測到這個穩定的形狀結構
#
#
#
#
#
# ### 在斜壓數值模式看
#
# 從x-y平面看位渦環(r=20)也是混到裡面(r=0)去
# 從r-z平面看，位渦環確實混進去且是底層從位渦環的位置(r=20~40km)混到中心(r=0)去，且最大量值下降有點像擴散進去
#
# 這是在Ooyama時代的理解
#
#
# 底層50km處v很大、旋轉很強、很穩定所以(Holland and Merrill(1984))[https://www.atmos.albany.edu/daes/atmclasses/atm527/Handouts_files/HollandMerrill_1984.pdf]才會畫出fig14那種圖，底層100km處左右會是空空的，實際上那邊是很強的位渦混和，是一個很強的內部結構，這邊產生對流東西、轉得很快很像鋼體東西都無法進去
#
#
#
# 所以就做3度空間的模擬
#
# 定義gamma factor (軸對稱指數)= 軸對稱平均/(軸對稱平均+非軸對稱的平均) $\gamma(r, z, t) \equiv \frac{\overline{\phi}(r, z, t)^2}{\overline{\phi}(r, z, t)^2 + \int_0^{2\pi} \phi'(r, \lambda, z, t)^2 \, d\lambda / 2\pi}$ Miyamoto and Takemi 2013，非軸對稱的情況該指數會很小、若完美軸對稱則指數=1
#
#
#
# 從 Kuo et al. 2019 MWR CReSS model 來看似乎所有變數($\overline{\gamma_v}^{RZ} , \overline{\gamma_{PV}}^{RZ} , \overline{\gamma_{rain}}^{RZ} ,\overline{\gamma_q}^{RZ},\overline{\gamma_{dia}}^{RZ}$)都隨著颱風變強而變得越來越軸對稱
# 這些符號分別代表不同變數在半徑-高度面 ($R$-$Z$ plane) 上的平均軸對稱度：$v$: 切向風速 (Tangential velocity)$PV$: 位渦 (Potential Vorticity)$rain$: 降雨率 (Rain rate)$q$: 水氣含量 (Specific humidity)$dia$: 絕熱加熱 (Diabatic heating)
#
# 而PV在變強的過程中似乎有一個週期 f(x) = ax+b , g(x)=sin(x2pi f ) ,似乎是 f+k*g(x) 的上升，k不是很大 ，從這張圖上來看一個週期大約16hr。
#
# 直接看模式850hPax-y切麵的PV，一開始中間空的，慢慢PV向內混合，(沒有解釋為什麼有這個16hr的週期)
#
# 如果看垂直的穩定度(逆溫層強度)，也可以從r-z圖看出來就是等溫線在颱風中心中層(500 hPa)下凹，凹到psudo height ~6km的位置(500 hPa)，所以有明顯的subsidence warming。所以可以得到結果，當底層50km處左右的位渦向內混和到底層(850hPa)中心，底層中心(850hPa,r=0km)的上方(500hPa,r=0)會有強大的下沉增溫。
# *  1991 年太平洋颶風 Jimena 的 眼牆內的探空觀測數據 (eye soundings)，就有觀察到伸到850hPa的沉降逆溫，這個很強的逆溫就是來自於PV的動力混和產生的沉降逆溫 (老師相信，但似乎沒有很具體的證明，不曉得有沒有更具體的證明)
# *
#
#
# ##### 根據方程式去argue
#
# !!內部應該說的是一個區域，大概是0~50km
#
# PV從r=50km底層混合>內部底層垂直穩定>內部中層有強大的垂直逆溫>內部中層增溫>導致底層壓力降低
#
# 底層壓力變低有兩種:
# * 水平壓力梯度大 (直橢圓),垂直壓力梯度小 (強颱風)
# * 水平壓力梯度小 (橫橢圓),垂直壓力梯度大 (弱颱風)
#
#
# PV從r=50km底層混合>會在底層50km處有非常強的u>根據$\frac{\partial u}{\partial t} + u \frac{\partial u}{\partial r}$ 會有非常強的非線性效應導致不連續的u (shock的出現)
#
# PV mixing near the core
#
# $\frac{\partial u}{\partial t} + u \frac{\partial u}{\partial r} = 0$
#
# BL PGF enhancement for u in strong TC
# $\frac{\partial v}{\partial t} \sim -\left( f + \frac{\partial(rv)}{r\partial r} \right) u$
#
# Shock u structure with w & ζ coupled
# $\frac{\partial ru}{r\partial r} + \frac{\partial w}{\partial z} = 0$
#
#
#
#
# Kuo et al. 2019 MWR
# * 綠色的線是v、黑色虛線是邊界層的u
# * r-t圖
# * 在邊界層的u產生shock的地方(25km,11/8號 00Z )，產生非常高密度的v等直線(v變化非常快)，Large ζ w coupled
# * 需要位渦的混和
#
# 另一張圖，把最大渦度和最大上升速度相乘，並用紅線標註Top 2% ζw
# *
#
#
# Tsujino and Kuo 2020 JAS
#
# * 做了2km、1km、0.5km解析度
# * 2km解析度只能夠模擬出100PVU，0.5km才能解析出200PVU
# * 2km解析度上升速度在眼牆區只有2m/s，0.5km才能上升速度在眼牆區可以到20m/s
# * 現在希望可以用GPU加快加大高解析的運算

# %% [markdown]
# ### IKE
#
# R34並不是一個好的變數，因為它只代表一個點，變異度可能很高、可能誤判、儀器誤差。IKE相對比較好它代表全域的颱風動能平均狀態
#
# 獨立性和相關性來說Vmax-IKE也比Vmax-R34好
#
# LMI(lifetime maxima intencity)最大v出現的時間點
# LME(lifetime maxima energy)最大IKE出現時間點
#
# Ooama的模式告訴你經過LMI後颱風雖然最大風速會下降但是還在繼續擴張導致IKE一直變大(這也是MPI理論缺乏的點，它只告訴你最大的V沒有告訴你IKE的情況)
#
#
#
# 在TC r=100km裡面加入多少熱量可以變成動能，加熱效率(Kuo et al. 2019 MWRTsujino san Tsuboki san )，200PVU的過程可以很高效的地把能量利用轉成動能
# * 利用Eliassen 方程式可以診斷多少能量$L \chi = \frac{g}{T_0} \frac{\partial T}{\partial r}$變成...環流? $L = \frac{\partial}{\partial r} \left( A \frac{\partial}{r \partial r} + B \frac{\partial}{\partial z} \right) + \frac{\partial}{\partial z} \left( B \frac{\partial}{r \partial r} + C \frac{\partial}{\partial z} \right)$
# *
# *
#
#
# BF chen 2025
# * 強矮人可以變成強巨人在變成弱巨人，這個過程就是雙眼牆過程才有的V-IKE反映
#
# 楊逸婷 2013
# 長生命期雙眼牆的特色是
# * 活超過24hr
# * moat很大
# * 渦度環很大
# *
#
# 西北太平洋控制TC變異度最大的是聖嬰現象，當聖嬰年時TC在中太平洋形成有非常長的時間可以動
# * 聖嬰年TC出現雙眼牆的比例會比反聖嬰年的還多，有些聖嬰年有雙眼牆的沒了雙眼牆後還可能再次雙眼牆
# * 外眼牆越寬加熱效率越好(恩但為什麼?)
# *
# **解釋**
# 雙眼牆的特色 moat很大 導致正壓不穩定的渦度大渦度小渦度大不是很適用，所以不會非常的正壓不穩定
#
# moat大的好處是，大部分的inflow都被外眼牆擋住而上升了，些微的inflow需要重新加速，所以厚的moat可以提供加速的空間，內部的眼牆的v才會大
#
#
# * 美國跟日本預報的颱風相關係數很高，但是到雙眼牆的颱風相關係數就驟降
#
# IKE的變異度是跟雙眼牆結構有關係的，尤其常生命期雙眼牆
